# %%
import pandas as pd
df = pd.read_csv('data.csv')
display(df.head())
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3              NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12575 entries, 0 to 12574
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    12575 non-null  str
#  1   Customer ID       12575 non-null  str
#  2   Category          12575 non-null  str
#  3   Item              11362 non-null  str
#  4   Price Per Unit    11966 non-null  float64
#  5   Quantity          11971 non-null  float64
#  6   Total Spent       11971 non-null  float64
#  7   Payment Method    12575 non-null  str
#  8   Location          12575 non-null  str
#  9   Transaction Date  12575 non-null  str
#  10  Discount Applied  8376 non-null   object
# dtypes: float64(3), object(1), str(7)
# memory usage: 1.9+ MB

# %%
print(df.isnull().sum())
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                1213
# Price Per Unit       609
# Quantity             604
# Total Spent          604
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64

# %%
df['Discount Applied'] = df['Discount Applied'].fillna(False)

# %%
df_clean = df.dropna()

# %%
df_clean = df_clean.copy() 
df_clean['Transaction Date'] = pd.to_datetime(df_clean['Transaction Date'])

# %%
print("عدد الصفوف المتبقية بعد التنظيف:", len(df_clean))
print("-" * 30)
print(df_clean.isnull().sum()) # يجب أن تكون كلها 0 الآن
# Out:
# عدد الصفوف المتبقية بعد التنظيف: 11362
# ------------------------------
# Transaction ID      0
# Customer ID         0
# Category            0
# Item                0
# Price Per Unit      0
# Quantity            0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# Discount Applied    0
# dtype: int64

# %%
df_clean.to_csv('cleaned_data.csv', index=False)
print("تم حفظ الملف باسم cleaned_data.csv بنجاح!")
# Out:
# تم حفظ الملف باسم cleaned_data.csv بنجاح!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# إعدادات لتبدو الرسومات احترافية وجميلة
sns.set_theme(style="whitegrid")

# %%
# قراءة البيانات النظيفة التي حفظناها سابقاً
df = pd.read_csv('cleaned_data.csv')

# %%
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'])

# %%
print("نحن جاهزون لبدء التحليل البصري!")
# Out:
# نحن جاهزون لبدء التحليل البصري!

# %%
plt.figure(figsize=(10, 6))

category_sales = df.groupby('Category')['Total Spent'].sum().sort_values(ascending=False)

# الكود المحدث
sns.barplot(x=category_sales.values, y=category_sales.index, hue=category_sales.index, palette='viridis', legend=False)

plt.title('إجمالي المبيعات حسب كل فئة (Total Sales by Category)', fontsize=14, fontweight='bold')
plt.xlabel('إجمالي المبيعات (Total Spent)')
plt.ylabel('الفئة (Category)')

plt.show()

# %%
plt.figure(figsize=(14, 5))

# إنشاء عمود جديد يحتوي على السنة والشهر فقط (مثال: 2023-07)
df['Month_Year'] = df['Transaction Date'].dt.to_period('M').astype(str)

# تجميع المبيعات حسب الشهر
monthly_sales = df.groupby('Month_Year')['Total Spent'].sum()

# رسم المنحنى
plt.plot(monthly_sales.index, monthly_sales.values, marker='o', color='b', linewidth=2)

plt.title('اتجاه المبيعات الشهري (Monthly Sales Trend)', fontsize=14, fontweight='bold')
plt.xlabel('الشهر (Month_Year)')
plt.ylabel('إجمالي المبيعات')

# تدوير التواريخ في المحور السفلي لتصبح قابلة للقراءة
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 5))

# رسم عدد العمليات حسب طريقة الدفع
sns.countplot(data=df, x='Payment Method', hue='Location', palette='Set2')

plt.title('طرق الدفع المفضلة مقسمة حسب موقع الشراء (Location)', fontsize=14, fontweight='bold')
plt.xlabel('طريقة الدفع (Payment Method)')
plt.ylabel('عدد العمليات (Transaction Count)')

plt.show()
